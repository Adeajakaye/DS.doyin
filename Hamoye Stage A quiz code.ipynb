# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Hamoye Stage A quiz code.ipynb',
#  'hamoyedata.csv',
#  'hamoyeVIZ.ipynb',
#  'map1.html',
#  'MAPPING',
#  'myexercise',
#  'mynames.txt',
#  'myprogramlist',
#  'myproject',
#  'MYWEBSITE',
#  'New Text Document.txt',
#  'number.txt',
#  'python for data visualization.ipynb',
#  'pythonHandbook',
#  'Untitled.ipynb']

# %%
import numpy as np

# %%
import pandas as pd

# %%
fuel_data=pd.read_csv("hamoyedata.csv ")

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#question 1

# %%
A=[1,2,3,4,5,6]
B=[13,21,34]
A_B=np.concatenate([A,B])

# %%
A_B
# Out:
# array([ 1,  2,  3,  4,  5,  6, 13, 21, 34])

# %%
#question 2

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#Question 3

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fuel_data.groupby("fuel_type_code_pudl")["fuel_cost_per_unit_burned"].min()
# Out:
# fuel_type_code_pudl
# coal         0.00
# gas          0.00
# nuclear      0.00
# oil          0.00
# other     -119.04
# waste     -276.08
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#Question 4

# %%
fuel_data.fuel_mmbtu_per_unit.describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
#Question 5

# %%
fuel_data.fuel_qty_burned.kurt()
# Out:
# 651.3694501337732

# %%
fuel_data.fuel_qty_burned.skew()
# Out:
# 15.851495469109503

# %%
#Question 6

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#question 10

# %%
year1=fuel_data[fuel_data["report_year"]==1998]

# %%
year1
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 4618     f1_fuel_1998_12_1_0_7                 1         1998
# 4619    f1_fuel_1998_12_1_0_10                 1         1998
# 4620     f1_fuel_1998_12_4_0_1                 4         1998
# 4621     f1_fuel_1998_12_4_0_2                 4         1998
# 4622     f1_fuel_1998_12_4_0_4                 4         1998
# ...                        ...               ...          ...
# 5720   f1_fuel_1998_12_145_2_2               145         1998
# 5721   f1_fuel_1998_12_145_2_3               145         1998
# 5722   f1_fuel_1998_12_145_2_6               145         1998
# 5723   f1_fuel_1998_12_145_2_9               145         1998
# 5724  f1_fuel_1998_12_145_2_12               145         1998
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 4618    rockport total aeg                coal       ton        4965881.0
# ...

# %%
year1.fuel_cost_per_unit_burned.sum()
# Out:
# 140238.65600000002

# %%
year2=fuel_data[fuel_data["report_year"]==1994]

# %%
year2.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
year2.fuel_cost_per_unit_burned.sum()
# Out:
# 263292.11500000005

# %%
#question 10

# %%
data=pd.DataFrame(fuel_data.groupby("report_year")["fuel_cost_per_unit_delivered"].sum())

# %%
data
# Out:
#              fuel_cost_per_unit_delivered
# report_year
# 1994                         7.859053e+04
# 1995                         3.931506e+04
# 1996                         1.000602e+07
# 1997                         1.218738e+07
# 1998                         3.178799e+05
# 1999                         2.682921e+04
# 2000                         1.352903e+06
# 2001                         8.142834e+04
# 2002                         5.735121e+04
# 2003                         6.740849e+04
# 2004                         1.663129e+05
# 2005                         5.258506e+04
# 2006                         4.805125e+04
# 2007                         5.476283e+04
# 2008                         7.194631e+04
# 2009                         7.975923e+05
# 2010                         1.158381e+05
# 2011                         7.412059e+04
# 2012                         7.581617e+04
# 2013                         2.065968e+05
# 2014                         2.256952e+05
# ...

# %%
data2=data/2

# %%
data2
# Out:
#              fuel_cost_per_unit_delivered
# report_year
# 1994                         3.929527e+04
# 1995                         1.965753e+04
# 1996                         5.003008e+06
# 1997                         6.093688e+06
# 1998                         1.589400e+05
# 1999                         1.341460e+04
# 2000                         6.764516e+05
# 2001                         4.071417e+04
# 2002                         2.867560e+04
# 2003                         3.370424e+04
# 2004                         8.315647e+04
# 2005                         2.629253e+04
# 2006                         2.402563e+04
# 2007                         2.738141e+04
# 2008                         3.597315e+04
# 2009                         3.987961e+05
# 2010                         5.791906e+04
# 2011                         3.706029e+04
# 2012                         3.790808e+04
# 2013                         1.032984e+05
# 2014                         1.128476e+05
# ...

# %%
pd.DataFrame(data2.max())
# Out:
#                                        0
# fuel_cost_per_unit_delivered  6093687.89
